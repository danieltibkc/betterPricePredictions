# %% [markdown]
# # Import relevant libraries & Data

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from -r requirements.txt (line 1)) (1.21.6)
# Requirement already satisfied: pandas in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from -r requirements.txt (line 2)) (1.3.5)
# Requirement already satisfied: matplotlib in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from -r requirements.txt (line 3)) (3.5.2)
# Requirement already satisfied: seaborn in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from -r requirements.txt (line 4)) (0.11.2)
# Requirement already satisfied: scikit-learn in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from -r requirements.txt (line 5)) (1.0.2)
# Requirement already satisfied: folium in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from -r requirements.txt (line 6)) (0.12.1.post1)
# Requirement already satisfied: scipy in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from -r requirements.txt (line 7)) (1.7.3)
# Requirement already satisfied: jupyter-dash in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from -r requirements.txt (line 8)) (0.4.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from pandas->-r requirements.txt (line 2)) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from pandas->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 3)) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 3)) (9.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 3)) (4.33.3)
# Requirement already satisfied: cycler>=0.10 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 3)) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 3)) (3.0.8)
# Requirement already satisfied: packaging>=20.0 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 3)) (21.3)
# Requirement already satisfied: joblib>=0.11 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from scikit-learn->-r requirements.txt (line 5)) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from scikit-learn->-r requirements.txt (line 5)) (3.1.0)
# Requirement already satisfied: branca>=0.3.0 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from folium->-r requirements.txt (line 6)) (0.5.0)
# Requirement already satisfied: jinja2>=2.9 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from folium->-r requirements.txt (line 6)) (3.1.2)
# Requirement already satisfied: requests in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from folium->-r requirements.txt (line 6)) (2.27.1)
# Requirement already satisfied: ipython in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from jupyter-dash->-r requirements.txt (line 8)) (7.33.0)
# Requirement already satisfied: ipykernel in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from jupyter-dash->-r requirements.txt (line 8)) (6.13.0)
# Requirement already satisfied: flask in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from jupyter-dash->-r requirements.txt (line 8)) (2.1.2)
# Requirement already satisfied: retrying in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from jupyter-dash->-r requirements.txt (line 8)) (1.3.3)
# Requirement already satisfied: dash in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from jupyter-dash->-r requirements.txt (line 8)) (2.3.1)
# Requirement already satisfied: nest-asyncio in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from jupyter-dash->-r requirements.txt (line 8)) (1.5.5)
# Requirement already satisfied: ansi2html in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from jupyter-dash->-r requirements.txt (line 8)) (1.7.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from jinja2>=2.9->folium->-r requirements.txt (line 6)) (2.1.1)
# Requirement already satisfied: typing-extensions in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib->-r requirements.txt (line 3)) (4.2.0)
# Requirement already satisfied: six>=1.5 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: importlib-metadata in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from ansi2html->jupyter-dash->-r requirements.txt (line 8)) (4.11.3)
# Requirement already satisfied: dash-table==5.0.0 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from dash->jupyter-dash->-r requirements.txt (line 8)) (5.0.0)
# Requirement already satisfied: flask-compress in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from dash->jupyter-dash->-r requirements.txt (line 8)) (1.12)
# Requirement already satisfied: dash-html-components==2.0.0 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from dash->jupyter-dash->-r requirements.txt (line 8)) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from dash->jupyter-dash->-r requirements.txt (line 8)) (2.0.0)
# Requirement already satisfied: plotly>=5.0.0 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from dash->jupyter-dash->-r requirements.txt (line 8)) (5.7.0)
# Requirement already satisfied: Werkzeug>=2.0 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from flask->jupyter-dash->-r requirements.txt (line 8)) (2.1.2)
# Requirement already satisfied: click>=8.0 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from flask->jupyter-dash->-r requirements.txt (line 8)) (8.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from flask->jupyter-dash->-r requirements.txt (line 8)) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from importlib-metadata->ansi2html->jupyter-dash->-r requirements.txt (line 8)) (3.8.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from plotly>=5.0.0->dash->jupyter-dash->-r requirements.txt (line 8)) (8.0.1)
# Requirement already satisfied: brotli in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from flask-compress->dash->jupyter-dash->-r requirements.txt (line 8)) (1.0.9)
# Requirement already satisfied: debugpy>=1.0 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from ipykernel->jupyter-dash->-r requirements.txt (line 8)) (1.6.0)
# Requirement already satisfied: psutil in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from ipykernel->jupyter-dash->-r requirements.txt (line 8)) (5.9.0)
# Requirement already satisfied: appnope in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from ipykernel->jupyter-dash->-r requirements.txt (line 8)) (0.1.3)
# Requirement already satisfied: traitlets>=5.1.0 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from ipykernel->jupyter-dash->-r requirements.txt (line 8)) (5.1.1)
# Requirement already satisfied: tornado>=6.1 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from ipykernel->jupyter-dash->-r requirements.txt (line 8)) (6.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from ipykernel->jupyter-dash->-r requirements.txt (line 8)) (7.3.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from ipykernel->jupyter-dash->-r requirements.txt (line 8)) (0.1.3)
# Requirement already satisfied: pexpect>4.3 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from ipython->jupyter-dash->-r requirements.txt (line 8)) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from ipython->jupyter-dash->-r requirements.txt (line 8)) (3.0.29)
# Requirement already satisfied: pygments in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from ipython->jupyter-dash->-r requirements.txt (line 8)) (2.12.0)
# Requirement already satisfied: backcall in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from ipython->jupyter-dash->-r requirements.txt (line 8)) (0.2.0)
# Requirement already satisfied: pickleshare in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from ipython->jupyter-dash->-r requirements.txt (line 8)) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from ipython->jupyter-dash->-r requirements.txt (line 8)) (62.1.0)
# Requirement already satisfied: decorator in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from ipython->jupyter-dash->-r requirements.txt (line 8)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from ipython->jupyter-dash->-r requirements.txt (line 8)) (0.18.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from jedi>=0.16->ipython->jupyter-dash->-r requirements.txt (line 8)) (0.8.3)
# Requirement already satisfied: pyzmq>=22.3 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash->-r requirements.txt (line 8)) (22.3.0)
# Requirement already satisfied: entrypoints in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash->-r requirements.txt (line 8)) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash->-r requirements.txt (line 8)) (4.10.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from pexpect>4.3->ipython->jupyter-dash->-r requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-dash->-r requirements.txt (line 8)) (0.2.5)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from requests->folium->-r requirements.txt (line 6)) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from requests->folium->-r requirements.txt (line 6)) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from requests->folium->-r requirements.txt (line 6)) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/esteban.tibaquira/opt/anaconda3/envs/betterprice-be/lib/python3.7/site-packages (from requests->folium->-r requirements.txt (line 6)) (2.0.12)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium.plugins import HeatMap
import plotly.express as px
sns.set()

# %%
df = pd.read_csv('data/train.csv');

# %% [markdown]
# # Basic EDA

# %% [markdown]
# ## First look at the dataset

# %%
# take a look at a couple of the first rows
df.head(3)
# Out:
#         id  log_price property_type        room_type  \
# 0  6901257   5.010635     Apartment  Entire home/apt
# 1  6304928   5.129899     Apartment  Entire home/apt
# 2  7919400   4.976734     Apartment  Entire home/apt
#
#                                            amenities  accommodates  bathrooms  \
# 0  {"Wireless Internet","Air conditioning",Kitche...             3        1.0
# 1  {"Wireless Internet","Air conditioning",Kitche...             7        1.0
# 2  {TV,"Cable TV","Wireless Internet","Air condit...             5        1.0
#
#    bed_type cancellation_policy  cleaning_fee  ...   latitude  longitude  \
# 0  Real Bed              strict          True  ...  40.696524 -73.991617
# 1  Real Bed              strict          True  ...  40.766115 -73.989040
# 2  Real Bed            moderate          True  ...  40.808110 -73.943756
#
#                                        name     neighbourhood  \
# 0            Beautiful brownstone 1-bedroom  Brooklyn Heights
# 1  Superb 3BR Apt Located Near Times Square    Hell's Kitchen
# 2                          The Garden Oasis            Harlem
#
#   number_of_reviews review_scores_rating  \
# 0                 2                100.0
# 1                 6                 93.0
# 2                10                 92.0
#
#                                        thumbnail_url zipcode bedrooms  beds
# 0  https://a0.muscache.com/im/pictures/6d7cbbf7-c...   11201      1.0   1.0
# 1  https://a0.muscache.com/im/pictures/348a55fe-4...   10019      3.0   3.0
# 2  https://a0.muscache.com/im/pictures/6fae5362-9...   10027      1.0   3.0
#
# [3 rows x 29 columns]

# %%
# How many rows and columns the DS has
print("Num cols", df.shape[1])
print("Num rows", df.shape[0])
# Out:
# Num cols 29
# Num rows 74111

# %%
# List columns, types and non-null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74111 entries, 0 to 74110
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      74111 non-null  int64
#  1   log_price               74111 non-null  float64
#  2   property_type           74111 non-null  object
#  3   room_type               74111 non-null  object
#  4   amenities               74111 non-null  object
#  5   accommodates            74111 non-null  int64
#  6   bathrooms               73911 non-null  float64
#  7   bed_type                74111 non-null  object
#  8   cancellation_policy     74111 non-null  object
#  9   cleaning_fee            74111 non-null  bool
#  10  city                    74111 non-null  object
#  11  description             74111 non-null  object
#  12  first_review            58247 non-null  object
#  13  host_has_profile_pic    73923 non-null  object
#  14  host_identity_verified  73923 non-null  object
#  15  host_response_rate      55812 non-null  object
#  16  host_since              73923 non-null  object
#  17  instant_bookable        74111 non-null  object
#  18  last_review             58284 non-null  object
#  19  latitude                74111 non-null  float64
#  20  longitude               74111 non-null  float64
#  21  name                    74111 non-null  object
#  22  neighbourhood           67239 non-null  object
#  23  number_of_reviews       74111 non-null  int64
#  24  review_scores_rating    57389 non-null  float64
#  25  thumbnail_url           65895 non-null  object
#  26  zipcode                 73145 non-null  object
#  27  bedrooms                74020 non-null  float64
#  28  beds                    73980 non-null  float64
# dtypes: bool(1), float64(7), int64(3), object(18)
# memory usage: 15.9+ MB

# %%
# Describe numerical features except the id
df.drop(columns=["id"], axis=1).describe()
# Out:
#           log_price  accommodates     bathrooms      latitude     longitude  \
# count  74111.000000  74111.000000  73911.000000  74111.000000  74111.000000
# mean       4.782069      3.155146      1.235263     38.445958    -92.397525
# std        0.717394      2.153589      0.582044      3.080167     21.705322
# min        0.000000      1.000000      0.000000     33.338905   -122.511500
# 25%        4.317488      2.000000      1.000000     34.127908   -118.342374
# 50%        4.709530      2.000000      1.000000     40.662138    -76.996965
# 75%        5.220356      4.000000      1.000000     40.746096    -73.954660
# max        7.600402     16.000000      8.000000     42.390437    -70.985047
#
#        number_of_reviews  review_scores_rating      bedrooms          beds
# count       74111.000000          57389.000000  74020.000000  73980.000000
# mean           20.900568             94.067365      1.265793      1.710868
# std            37.828641              7.836556      0.852143      1.254142
# min             0.000000             20.000000      0.000000      0.000000
# 25%             1.000000             92.000000      1.000000      1.000000
# 50%             6.000000             96.000000      1.000000      1.000000
# 75%            23.000000            100.000000      1.000000      2.000000
# max           605.000000            100.000000     10.000000     18.000000

# %%
# Visualize missing values
plt.figure(figsize=(12, 8))
sns.heatmap(df.isnull(), yticklabels=False, cbar=False)
# Out:
# <AxesSubplot:>

# %%
# Get last quantiles for relevant quantifiable numerical features
df[['log_price', 'accommodates', 'bathrooms', 'bedrooms', 'beds' ]].quantile([0.90, 0.95, 0.99])
# Out:
#       log_price  accommodates  bathrooms  bedrooms  beds
# 0.90   5.703782           6.0        2.0       2.0   3.0
# 0.95   6.052089           7.0        2.0       3.0   4.0
# 0.99   6.894467          12.0        3.5       4.0   6.0

# %% [markdown]
# Right away I can start to identify what kind of features I can work with and what can be ignored.
#
# Things like the URL for the thumbnail, description, first review, name won't add value to our predictions.
#
# Since ML models only work with numerical data, there're several features that will have to be transform in order to use them. We have categorical columns:
#
# - property_type
# - room_type
# - bed_type
# - cancellation_policy
# - city
# - instant_bookable
# - neighbourhood
#
# One of the most important column is "Amenities", right now it's a dictionary, when we tranform it to columns, our data will get very wide and that's something to keep in mind.
#
# Regarding null values, fortunately most of them belong to columns that we won't be using, so all in all it's a pretty clean dataset

# %%
# Drop columns we will not be using
df.drop(columns=['description', 'first_review', 'host_has_profile_pic', 'host_identity_verified', 'host_response_rate', 'host_since', 'last_review', 'name', 'thumbnail_url'], inplace=True)

# %% [markdown]
# ## Visualizing the data

# %% [markdown]
# ### Quantifiable

# %%
sns.histplot(df['log_price'], bins=50, kde=True)
plt.title('Price density plot')
# Out:
# Text(0.5, 1.0, 'Price density plot')

# %% [markdown]
# We have to be careful of how we handle the price, since it's in a logarithmic scale and not in USD as one would expect

# %%
sns.histplot(df['accommodates'], bins=15)
# Out:
# <AxesSubplot:xlabel='accommodates', ylabel='Count'>

# %%
sns.histplot(df['bathrooms'], bins=10)
# Out:
# <AxesSubplot:xlabel='bathrooms', ylabel='Count'>

# %%
sns.histplot(df['bedrooms'], bins=10)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='Count'>

# %%
sns.histplot(df['beds'], bins=10)
# Out:
# <AxesSubplot:xlabel='beds', ylabel='Count'>

# %% [markdown]
# From this general view, one could far fetch that most places are small, or focused on small group of renters. Since, we see a high pick in places that accommodate less than 4 people, also most places have less than 3 bedrooms

# %% [markdown]
# ### Correlations against Price

# %% [markdown]
# This is a pretty important section since here we would compare most features and identity how they increase/decrase the price of an AirBnB. From the things we can find here we can construct the final form of the app.

# %%
# General correlation between all features
sns.set(font_scale=1.5)
plt.figure(figsize=(18,18))
sns.heatmap(df.corr(), cmap='seismic', annot=True, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Unsurprisingly, at a first glance we can see that the feature that are the most positively correlated to the price are the Accomodates, Bathrooms, Bedrooms and Beds. This can be helpful information, when asking the users about their place.
#
# For me it's weird that, number of reviews influences negatively the price of a place and that the review scores rating aren't adding that much value, since one strategy airbnb offers for filtering is the reviews.
#
# Having this results in mind let's look specifically at this features.

# %%
sns.set(font_scale= 1)
sns.boxplot(x='accommodates', y='log_price', data=df)
plt.title('Boxplot: Price vs Accomodates')
# Out:
# Text(0.5, 1.0, 'Boxplot: Price vs Accomodates')

# %%
sns.boxplot(x='bathrooms', y='log_price', data=df)
plt.title('Boxplot: Price vs Bathrooms')
# Out:
# Text(0.5, 1.0, 'Boxplot: Price vs Bathrooms')

# %%
sns.boxplot(x='bedrooms', y='log_price', data=df)
plt.title('Boxplot: Price vs Bedrooms')
# Out:
# Text(0.5, 1.0, 'Boxplot: Price vs Bedrooms')

# %%
sns.boxplot(x='beds', y='log_price', data=df)
plt.title('Boxplot: Price vs Beds')
# Out:
# Text(0.5, 1.0, 'Boxplot: Price vs Beds')

# %% [markdown]
# This gives us a clearer understanding of how the data is distribuited. Accommodates and Bedrooms are very uniform. On the other hand Bathrooms and Beds have a some outliers but still we can visualize that generally the higher the amount, the higher the price.
#
# This phase is not over, it definitely should be revisited once we have feature engineer'ed categorical variables like the city, neighbourghood, and ammenities.
#
# Something that comes to mind is that the latitude and longitude should also be an important factor, but, as this kind of data has such a high spread, it's hard to determine anything yet, anyway I would gravitate towards using the City+Neighbourhood to draw conclusions regarding the location. Another solution would be to adjust lat and long to have a higher radius, so that it can be in a more delimited space, the down side is that this would turn it into a categorical feature.

# %% [markdown]
# ### Categorical Features

# %%
# Property Type
plt.figure(figsize=(12, 12))
sns.countplot(y='property_type', data=df, order=df['property_type'].value_counts().index)
plt.ylabel('Property Type', fontsize=20, weight='bold')
# Out:
# Text(0, 0.5, 'Property Type')

# %%
# Room type
plt.figure(figsize=(8, 8))
sns.countplot(y='room_type', data=df, order=df['room_type'].value_counts().index)
plt.ylabel('Room Type', fontsize=20, weight='bold')
# Out:
# Text(0, 0.5, 'Room Type')

# %%
# Cancellation Policy
plt.figure(figsize=(8, 8))
sns.countplot(y='cancellation_policy', data=df, order=df['cancellation_policy'].value_counts().index)
plt.ylabel('Cancellation Policy', fontsize=20, weight='bold')
# Out:
# Text(0, 0.5, 'Cancellation Policy')

# %%
plt.figure(figsize = (12,12))
# Only the first 10 most visited
data = df.neighbourhood.value_counts()[:10]
plt.figure(figsize=(10,10))

x = data.index
y = data.values

plt.title("Most popular Neighbourhood")
plt.xlabel("Neighbourhood Area")
plt.ylabel("Number of guest who host in this area")
plt.xticks(rotation=45)
plt.bar(x,y)
# Out:
# <BarContainer object of 10 artists>

# %%
plt.figure(figsize=(8,8))
sns.countplot(y = 'city',data = df,order = df['city'].value_counts().index)
plt.ylabel('City',fontsize = 20, weight = 'bold')
plt.show()

# %% [markdown]
# Looking at the property type variable we can see that there are several types that have way to low values, maybe we can encapsule them into one or multiple types so that we dont end up with data so skewed.
#
# As there are so many neighbourhoods we have to think of how to manage this in tandem with the city variable

# %% [markdown]
# ### Visualizing location data

# %%
def create_map(city='NYC'):
    price_view = lambda x: 'price: ' + str(round(x, 2))

    fraction = 0.6
    # This cities have a larger area with places to rent
    if city in {'NYC', 'LA'}:
        fraction = 0.2

    df_temp = df[df['city'] == city].sample(frac=fraction, random_state=123)
    df_temp['log_price'] = np.round(df_temp['log_price'], 2)

    fig = px.scatter_mapbox(
        df_temp,
        lat='latitude',
        lon='longitude',
        hover_data=['log_price'],
        color='log_price',
        zoom=10
    )

    fig.update_layout(
        title=f'AirBnB prices in {city}',
        geo_scope='usa',
        width=1000,
        height=600,
        mapbox_style='white-bg',
        mapbox_layers=[{
            "below": 'traces',
            "sourcetype": "raster",
            "sourceattribution": "United States Geological Survey",
            "source": ["https://basemap.nationalmap.gov/arcgis/rest/services/USGSImageryOnly/MapServer/tile/{z}/{y}/{x}"]
        }]
    )

    fig.show()

# %%
create_map('Chicago')
